# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("titanic.csv")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# Missing values check
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Age -> median
df['Age'] = df['Age'].fillna(df['Age'].median())

# Embarked -> mode
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Cabin -> Unknown ya drop
df['Cabin'] = df['Cabin'].fillna('Unknown')
# ya
# df.drop('Cabin', axis=1, inplace=True)

# %%
# Verify
print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#who servived more males or female
survival_by_gender = df.groupby('Sex')['Survived'].sum()
print(survival_by_gender)
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
#passenger class affect servival chances
df.groupby('Pclass')['Survived'].mean() * 100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
survival_rate = df.groupby('Pclass')['Survived'].agg(['count', 'sum', 'mean'])
print(survival_rate)
# Out:
#         count  sum      mean
# Pclass
# 1         216  136  0.629630
# 2         184   87  0.472826
# 3         491  119  0.242363

# %%
df.groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
# Servival rate by age group
bins = [0, 12, 18, 35, 60, 100]
labels = ['Child', 'Teen', 'Young Adult', 'Adult', 'Senior']

df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
df.groupby('AgeGroup', observed=True)['Survived'].mean() * 100
# Out:
# AgeGroup
# Child          57.971014
# Teen           42.857143
# Young Adult    35.327103
# Adult          40.000000
# Senior         22.727273
# Name: Survived, dtype: float64

# %%
# Bar chart of survival by gender
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title('Survival Count by Gender')
plt.show()

# %%
# Bar chart of survival by class
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title('Survival Count by Passenger Class')
plt.show()

# %%
# histogram of passenger
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Distribution of Passenger Ages')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
